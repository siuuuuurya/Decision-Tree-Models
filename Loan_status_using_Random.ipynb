# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("/Users/siuuuuurya/Desktop/excelfiles/loan_data_for_Random_forest.csv")
pd
# Out:
# <module 'pandas' from '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/__init__.py'>

# %%
df
# Out:
#     Gender Married     Education  ApplicantIncome  LoanAmount Loan_Status  \
# 0     Male     Yes      Graduate             5000         200           Y
# 1   Female      No      Graduate             3000         100           N
# 2     Male     Yes  Not Graduate             4000         150           Y
# 3     Male      No      Graduate             2000          80           N
# 4   Female     Yes      Graduate             2500         120           Y
# 5   Female      No  Not Graduate             3500         110           N
# 6     Male     Yes      Graduate             6000         250           Y
# 7     Male     Yes  Not Graduate             4000         160           Y
# 8   Female      No      Graduate             2200          90           N
# 9     Male     Yes  Not Graduate             5800         210           Y
# 10    Male      No      Graduate             3300         130           Y
# 11  Female     Yes      Graduate             2700         100           N
# ...

# %%
df.isnull().sum()
# Out:
# Gender              0
# Married             0
# Education           0
# ApplicantIncome     0
# LoanAmount          0
# Loan_Status         0
# Unnamed: 6         16
# dtype: int64

# %%
df = df.drop(['Unnamed: 6'], axis = 1)

# %%
df
# Out:
#     Gender Married     Education  ApplicantIncome  LoanAmount Loan_Status
# 0     Male     Yes      Graduate             5000         200           Y
# 1   Female      No      Graduate             3000         100           N
# 2     Male     Yes  Not Graduate             4000         150           Y
# 3     Male      No      Graduate             2000          80           N
# 4   Female     Yes      Graduate             2500         120           Y
# 5   Female      No  Not Graduate             3500         110           N
# 6     Male     Yes      Graduate             6000         250           Y
# 7     Male     Yes  Not Graduate             4000         160           Y
# 8   Female      No      Graduate             2200          90           N
# 9     Male     Yes  Not Graduate             5800         210           Y
# 10    Male      No      Graduate             3300         130           Y
# 11  Female     Yes      Graduate             2700         100           N
# ...

# %%
df
# Out:
#     Gender Married     Education  ApplicantIncome  LoanAmount Loan_Status
# 0     Male     Yes      Graduate             5000         200           Y
# 1   Female      No      Graduate             3000         100           N
# 2     Male     Yes  Not Graduate             4000         150           Y
# 3     Male      No      Graduate             2000          80           N
# 4   Female     Yes      Graduate             2500         120           Y
# 5   Female      No  Not Graduate             3500         110           N
# 6     Male     Yes      Graduate             6000         250           Y
# 7     Male     Yes  Not Graduate             4000         160           Y
# 8   Female      No      Graduate             2200          90           N
# 9     Male     Yes  Not Graduate             5800         210           Y
# 10    Male      No      Graduate             3300         130           Y
# 11  Female     Yes      Graduate             2700         100           N
# ...

# %%
encoded1 = LabelEncoder()
encoded2 = LabelEncoder()
df['Gender_encoded'] = encoded.fit_transform(df['Gender'])
df['Married_encoded'] = encoded.fit_transform(df['Married'])

# %%
encoded3 = LabelEncoder()
df['Encoded_Education'] = encoded.fit_transform(df['Education'])

# %%
df = df.drop(['Gender','Education','Married'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df = df.drop(['Gender','Education','Married'], axis = 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
df
# Out:
#     ApplicantIncome  LoanAmount Loan_Status  Gender_encoded  Married_encoded  \
# 0              5000         200           Y               1                1
# 1              3000         100           N               0                0
# 2              4000         150           Y               1                1
# 3              2000          80           N               1                0
# 4              2500         120           Y               0                1
# 5              3500         110           N               0                0
# 6              6000         250           Y               1                1
# 7              4000         160           Y               1                1
# 8              2200          90           N               0                0
# 9              5800         210           Y               1                1
# 10             3300         130           Y               1                0
# ...

# %%
X = df.drop('Loan_status_encoded', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 X = df.drop('Loan_status_encoded', axis = 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
Y = df.Loan_status_encoded

# %%
X
# Out:
#     ApplicantIncome  LoanAmount  Gender_encoded  Married_encoded  \
# 0              5000         200               1                1
# 1              3000         100               0                0
# 2              4000         150               1                1
# 3              2000          80               1                0
# 4              2500         120               0                1
# 5              3500         110               0                0
# 6              6000         250               1                1
# 7              4000         160               1                1
# 8              2200          90               0                0
# 9              5800         210               1                1
# 10             3300         130               1                0
# 11             2700         100               0                1
# 12             3100         170               1                1
# ...

# %%
Y
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    1
# 13    0
# 14    1
# 15    0
# Name: Loan_status_encoded, dtype: int64

# %% [markdown]
# # Model decleration

# %%
Model = RandomForestClassifier(n_estimators = 100, random_state = 42)

# %%
x_train , x_test , y_train , y_test = train_test_split( X , Y, test_size=0.2 )

# %%
X
# Out:
#     ApplicantIncome  LoanAmount  Gender_encoded  Married_encoded  \
# 0              5000         200               1                1
# 1              3000         100               0                0
# 2              4000         150               1                1
# 3              2000          80               1                0
# 4              2500         120               0                1
# 5              3500         110               0                0
# 6              6000         250               1                1
# 7              4000         160               1                1
# 8              2200          90               0                0
# 9              5800         210               1                1
# 10             3300         130               1                0
# 11             2700         100               0                1
# 12             3100         170               1                1
# ...

# %%
Y
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    1
# 13    0
# 14    1
# 15    0
# Name: Loan_status_encoded, dtype: int64

# %%
df
# Out:
#     ApplicantIncome  LoanAmount Loan_Status  Gender_encoded  Married_encoded  \
# 0              5000         200           Y               1                1
# 1              3000         100           N               0                0
# 2              4000         150           Y               1                1
# 3              2000          80           N               1                0
# 4              2500         120           Y               0                1
# 5              3500         110           N               0                0
# 6              6000         250           Y               1                1
# 7              4000         160           Y               1                1
# 8              2200          90           N               0                0
# 9              5800         210           Y               1                1
# 10             3300         130           Y               1                0
# ...

# %%
Model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
Model.predict(x_test)
# Out:
# array([1, 0, 1, 0])
